# %%
import pandas as pd

# %%
# PATH_WINDOWS = '..\\data\\round1\\prices_round_'
# PATH_LINUX = '..\data\round1\prices_round_'
PATH_MAC = '/Users/albertyang/Desktop/IMC_Prosperity/data/round-1-island-data-bottle/prices_round_'

# %%
path = PATH_MAC
round = 1

data0 = pd.read_csv(filepath_or_buffer = f'{path}{round}_day_0.csv', sep=';')
data1 = pd.read_csv(filepath_or_buffer = f'{path}{round}_day_-1.csv', sep=';')
data2 = pd.read_csv(filepath_or_buffer = f'{path}{round}_day_-2.csv', sep=';')

# %%
data_kelp0 = data0.loc[data0['product'] == 'KELP']
data_kelp1 = data1.loc[data1['product'] == 'KELP']
data_kelp2 = data2.loc[data2['product'] == 'KELP']

# %%
# data_pearls = data0[data0['product'] == 'PEARLS']

# %%
data_pearls
# Out:
# Empty DataFrame
# Columns: [day, timestamp, product, bid_price_1, bid_volume_1, bid_price_2, bid_volume_2, bid_price_3, bid_volume_3, ask_price_1, ask_volume_1, ask_price_2, ask_volume_2, ask_price_3, ask_volume_3, mid_price, profit_and_loss]
# Index: []

# %% [markdown]
# # Spread in banans

# %%
data_kelp0['spread'] = data_kelp0['bid_price_1'] - data_kelp0['ask_price_1']
data_kelp1['spread'] = data_kelp1['bid_price_1'] - data_kelp1['ask_price_1']
data_kelp2['spread'] = data_kelp2['bid_price_1'] - data_kelp2['ask_price_1']
# Out:
# /var/folders/hh/5kl2vn091f5_4vrvb7_9hthh0000gn/T/ipykernel_32034/2298530816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_kelp0['spread'] = data_kelp0['bid_price_1'] - data_kelp0['ask_price_1']
# /var/folders/hh/5kl2vn091f5_4vrvb7_9hthh0000gn/T/ipykernel_32034/2298530816.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_kelp1['spread'] = data_kelp1['bid_price_1'] - data_kelp1['ask_price_1']
# ...

# %%
data_kelp0['spread'].describe()
# Out:
# count    10000.000000
# mean        -2.729200
# std          0.882465
# min         -4.000000
# 25%         -3.000000
# 50%         -3.000000
# 75%         -2.000000
# max         -1.000000
# Name: spread, dtype: float64

# %%
data_kelp1['spread'].describe()
# Out:
# count    10000.000000
# mean        -2.715200
# std          0.879867
# min         -4.000000
# 25%         -3.000000
# 50%         -3.000000
# 75%         -2.000000
# max         -1.000000
# Name: spread, dtype: float64

# %%
data_kelp2['spread'].describe()
# Out:
# count    10000.000000
# mean        -2.692200
# std          0.881781
# min         -4.000000
# 25%         -3.000000
# 50%         -3.000000
# 75%         -2.000000
# max         -1.000000
# Name: spread, dtype: float64

# %%
data_kelp0['mid_price'].plot()
# Out:
# <Axes: >

# %%
data_kelp1['mid_price'].plot()
# Out:
# <Axes: >

# %%
data_kelp2['mid_price'].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Order distribution in kelps

# %%
data_kelp0['n_bids'] = data_kelp0['bid_price_1'] + data_kelp0['bid_price_2'] + data_kelp0['bid_price_3']
data_kelp0['n_asks'] = data_kelp0['ask_price_1'] + data_kelp0['ask_price_2'] + data_kelp0['ask_price_3']
# Out:
# /var/folders/hh/5kl2vn091f5_4vrvb7_9hthh0000gn/T/ipykernel_32034/1743717389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_kelp0['n_bids'] = data_kelp0['bid_price_1'] + data_kelp0['bid_price_2'] + data_kelp0['bid_price_3']
# /var/folders/hh/5kl2vn091f5_4vrvb7_9hthh0000gn/T/ipykernel_32034/1743717389.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_kelp0['n_asks'] = data_kelp0['ask_price_1'] + data_kelp0['ask_price_2'] + data_kelp0['ask_price_3']

# %%
data_kelp0['n_bids'].describe()
# Out:
# count     168.000000
# mean     6101.738095
# std         6.596350
# min      6081.000000
# 25%      6099.000000
# 50%      6102.500000
# 75%      6106.000000
# max      6114.000000
# Name: n_bids, dtype: float64

# %%
data_kelp0['n_asks'].describe()
# Out:
# count     195.000000
# mean     6106.579487
# std         6.622174
# min      6084.000000
# 25%      6104.000000
# 50%      6108.000000
# 75%      6111.000000
# max      6120.000000
# Name: n_asks, dtype: float64

# %%
data_kelp0['profit_and_loss'].plot()
# Out:
# <Axes: >

# %%
trades = pd.read_csv('..\\data\\round1\\trades_round_1_day_-1_nn.csv', sep = ';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 trades = pd.read_csv('..\\data\\round1\\trades_round_1_day_-1_nn.csv', sep = ';')
#
# ...

# %%
trades['seller'].value_counts(dropna=False)
# Out:
# NaN    5279
# Name: seller, dtype: int64
